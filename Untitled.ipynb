# %%
from bs4 import BeautifulSoup
import requests
from csv import writer

url = 'https://www.takealot.com/deals?sort=Relevance'
page = requests.get(url)

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
lists = soup.find_all('div',class_='product-card_fdqa8')
print(lists)
# Out:
# []

# %%
# with open('takealot.csv','w', encoding='utf8',newline='') as f:
#     thewriter = writer(f)
#     header = ['Title']
#     thewriter.writerow(header)
for list in lists:
#         ondeal = list.find('div', class_='search-product grid deals').text.replace('\n','')
    title = list.find('div', class_='product-card-module_title-wrapper_1sj9D')
    price = list.find('div', class_='product-card-module_price-wrapper_2waB1')
#         originalprice = list.find('li', class_='list-price product-card-module_list-price_2IA5c').text.replace('\n','')
    info = [title, price]
    print(info)
#         info = [title]
#         print(info)
#         thewriter.writerow(info)
