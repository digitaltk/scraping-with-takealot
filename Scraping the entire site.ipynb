# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

baseurl = "https://www.babiesrus.co.za/"

headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36'}
productlinks = []
t={}
data=[]
c=0
for x in range(1,6):
    k = requests.get('https://www.babiesrus.co.za/shop-by-department'.format(x)).text
    soup=BeautifulSoup(k,'html.parser')
    productlist = soup.find_all("li",{"class":"item product product-item"})


for product in productlist:
     link = product.find("a",{"class":"product photo product-item-photo"}).get('href')
     productlinks.append(baseurl + link)

# %%
for link in productlinks:
    f = requests.get(link,headers=headers).text
    hun=BeautifulSoup(f,'html.parser')

    try:
        price=hun.find("span",{"class":"price"}).text.replace('\n',"")
    except:
        price = None

    try:
        name=hun.find("a",{"class":"product-item-link"}).text.replace('\n',"")
    except:
        name=None

    try:
        brand = hun.find("div",{"class":"product-item-brand"}).text.replace('\n',"")
    except:
        brand=None

    try:
        img=hun.find("img",{"class":"product-image-photo"})
    except:
        img=None

    babyproducts = {"price":price,"name":name,"brand":brand,"img":img}

    data.append(babyproducts)
    c=c+1
    print("completed",c)

df = pd.DataFrame(data)

print(df)
# Out:
# completed 1
# completed 2
# completed 3
# completed 4
# completed 5
# completed 6
# completed 7
# completed 8
# completed 9
# completed 10
# completed 11
# completed 12
# completed 13
# completed 14
# completed 15
# completed 16
# completed 17
# completed 18
# completed 19
# completed 20
# completed 21
# completed 22
# completed 23
# completed 24
# completed 25
# completed 26
# completed 27
# completed 28
# completed 29
# completed 30
# completed 31
# completed 32
# completed 33
# completed 34
# completed 35
# completed 36
# completed 37
# completed 38
# completed 39
# completed 40
#     price  name brand   img
# 0   R0.00  None  None  None
# 1   R0.00  None  None  None
# 2   R0.00  None  None  None
# 3   R0.00  None  None  None
# 4   R0.00  None  None  None
# 5   R0.00  None  None  None
# 6   R0.00  None  None  None
# 7   R0.00  None  None  None
# 8   R0.00  None  None  None
# 9   R0.00  None  None  None
# 10  R0.00  None  None  None
# 11  R0.00  None  None  None
# ...

# %%
print(df)
# Out:
#     price  name brand   img
# 0   R0.00  None  None  None
# 1   R0.00  None  None  None
# 2   R0.00  None  None  None
# 3   R0.00  None  None  None
# 4   R0.00  None  None  None
# 5   R0.00  None  None  None
# 6   R0.00  None  None  None
# 7   R0.00  None  None  None
# 8   R0.00  None  None  None
# 9   R0.00  None  None  None
# 10  R0.00  None  None  None
# 11  R0.00  None  None  None
# 12  R0.00  None  None  None
# 13  R0.00  None  None  None
# 14  R0.00  None  None  None
# 15  R0.00  None  None  None
# 16  R0.00  None  None  None
# 17  R0.00  None  None  None
# 18  R0.00  None  None  None
# 19  R0.00  None  None  None
# 20  R0.00  None  None  None
# 21  R0.00  None  None  None
# 22  R0.00  None  None  None
# 23  R0.00  None  None  None
# 24  R0.00  None  None  None
# 25  R0.00  None  None  None
# 26  R0.00  None  None  None
# 27  R0.00  None  None  None
# 28  R0.00  None  None  None
# 29  R0.00  None  None  None
# 30  R0.00  None  None  None
# 31  R0.00  None  None  None
# ...
